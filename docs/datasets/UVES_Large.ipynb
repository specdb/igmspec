# %% [markdown]
# # UVES Large Programme and a bit more
#
# http://adsabs.harvard.edu/abs/2008A%26A...491..465D

# %%
# %matplotlib notebook

# %%
# imports
from matplotlib import pyplot as plt
from linetools.spectra import io as lsio

# %% [markdown]
# ## Summary Table

# %%
meta_file = os.getenv('RAW_IGMSPEC')+'/UVES_Dall/uves_dall_summ.dat'

# %%
meta = Table.read(meta_file, format='ascii')

# %%
meta[0:5]
# Out:
# <Table length=5>
#     NAME         RA         DEC            OBS-DATE
#    str11       str11       str11            str22
# ----------- ----------- ----------- ----------------------
# HE0001-2340 00:03:44.92 -23:23:54.8 2001-06-29T08:20:37.72
#   Q0002-422 00:04:48.28 -41:57:28.1 2001-07-15T09:13:54.34
#   Q0055-269 00:57:58.00 -26:43:14.9 2000-09-21T02:03:09.30
#  Q0109-3518 01:11:43.62 -35:03:00.4 2001-08-24T08:34:40.76
#   Q0122-380 01:24:17.38 -37:44:22.9 2000-10-9T02:58:56.956

# %% [markdown]
# ## Data file

# %%
dfile = os.getenv('RAW_IGMSPEC')+'/UVES_Dall/Q0216+08_flux.dat'

# %%
dtbl = Table.read(dfile,format='ascii.fast_no_header',guess=False)#, data_start=1)

# %%
dtbl[0:3]
# Out:
# <Table length=3>
#   col1    col2    col3    col4
# float64 float64 float64 float64
# ------- ------- ------- -------
#  3000.0     0.0     0.0     0.0
# 3000.05     0.0     0.0     0.0
#  3000.1     0.0     0.0     0.0

# %%
plt.clf()
plt.plot(dtbl['col1'], dtbl['col2'], 'k')
plt.plot(dtbl['col1'], dtbl['col3'], 'r')
plt.plot(dtbl['col1'], dtbl['col4'], 'g')
# Out:
# <img src="data:image/png;base64,...">
