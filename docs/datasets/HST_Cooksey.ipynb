# %% [markdown]
# # HST+FUSE AGN spectra compiled by Cooksey et al. 2011

# %%
# imports
from astropy.table import Table
from astropy.io.fits import Header

from linetools.spectra import io as lsio

# %% [markdown]
# ## Meta

# %%
meta_file = os.getenv('RAW_IGMSPEC')+'/HST_Cooksey/HSTQSO_pre-SM4.lst'

# %%
meta = Table.read(meta_file, format='ascii')

# %%
meta[0:3]
# Out:
# <Table length=3>
#  QSO      RA     DEC      zem           Ref         INSTR    SPEC_FILE
# str22  float64 float64  float64        str20         str4      str40
# ------ ------- -------- ------- ------------------- ----- ----------------
# MRK335 1.58133 20.20289 0.02578 1999ApJS..121..287H  FUSE MRK335lif2b.fits
# MRK335 1.58133 20.20289 0.02578 1999ApJS..121..287H  FUSE MRK335sic1a.fits
# MRK335 1.58133 20.20289 0.02578 1999ApJS..121..287H  FUSE MRK335sic2a.fits

# %% [markdown]
# ## Read FUSE

# %% [markdown]
# ### LIF 2A

# %%
fuse_file = os.getenv('RAW_IGMSPEC')+'/HST_Cooksey/NGC4151/FUSE/NGC4151lif2a.fits'

# %%
reload(lsio)
fuse = lsio.readspec(fuse_file, head_ext=1)

# %%
fuse.header['HISTORY']
# Out:
# SIMPLE  =                    T / Data conforms to FITS standard
# BITPIX  =                   16 / Bits per data value
# NAXIS   =                    0 / Number of data axes
# EXTEND  =                    T / File may contain standard extensions
# NEXTEND =                    1 / Number of standard extensions
# GROUPS  =                    F / Image is in group format
# DATE    = '2007-04-23T08:57:27' / file creation date (YYYY-MM-DDThh:mm:s
#
#               DATA DESCRIPTION KEYWORDS
#
# TELESCOP= 'FUSE              ' / Telescope used to acquire data
# INSTRUME= 'FUV               ' / Instrument in use (one of FUV, FESA, or
# ROOTNAME= 'C0920101999'        / Rootname of the observation set (pppptt
# FILENAME= 'C09201019992alif4ttagfcal.fit' / Name of file
# FILETYPE= 'CALIBRATED EXTRACTED SPECTRUM' / Type of data found in data f
# EXP_STAT=                    0 / Science data processing status (0=good)
#
#               PROPOSAL INFORMATION
#
# ...

# %% [markdown]
# ### SIC 2A

# %%
sic2a_file = os.getenv('RAW_IGMSPEC')+'/HST_Cooksey/MRK335/FUSE/MRK335sic2a.fits'

# %%
hdu = fits.open(sic2a_file)

# %%
hdu.info()
# Out:
# Filename: /u/xavier/Raw_IGMspec/HST_Cooksey/MRK335/FUSE/MRK335sic2a.fits
# No.    Name         Type      Cards   Dimensions   Format
# 0    PRIMARY     PrimaryHDU       4   ()
# 1                BinTableHDU    495   1R x 3C      [6690D, 6690D, 6690D]

# %%
head1 = hdu[1].header

# %%
hdu[1].verify('fix')

# %%
data = hdu[1].data

# %%
tbl = Table(hdu[1].data)

# %% [markdown]
# ### Bad header?

# %%
ifile = '/u/xavier/Raw_IGMspec/HST_Cooksey/B0312-770/FUSE/B0312-770sic2a.fits'

# %%
hdu_badhd = fits.open(ifile)

# %%
hdu_badhd.info()
# Out:
# Filename: /u/xavier/Raw_IGMspec/HST_Cooksey/B0312-770/FUSE/B0312-770sic2a.fits
# No.    Name         Type      Cards   Dimensions   Format
# 0    PRIMARY     PrimaryHDU     379   ()
# 1    SPECTRUM    BinTableHDU     35   7694R x 7C   [1E, 1E, 1E, 1J, 1E, 1E, 1I]

# %%
hdu_badhd[0].header
# Out:
# SIMPLE  =                    T / Data conforms to FITS standard
# BITPIX  =                   16 / Bits per data value
# NAXIS   =                    0 / Number of data axes
# EXTEND  =                    T / File may contain standard extensions
# NEXTEND =                    1 / Number of standard extensions
# GROUPS  =                    F / Image is in group format
# DATE    = '2007-04-22T00:50:55' / file creation date (YYYY-MM-DDThh:mm:ss UT)
#
#               DATA DESCRIPTION KEYWORDS
#
# TELESCOP= 'FUSE              ' / Telescope used to acquire data
# INSTRUME= 'FUV               ' / Instrument in use (one of FUV, FESA, or FESB)
# ROOTNAME= 'E8480201999'        / Rootname of the observation set (ppppttooeee)
# FILENAME= 'E84802019992asic4ttagfcal.fit' / Name of file
# FILETYPE= 'CALIBRATED EXTRACTED SPECTRUM' / Type of data found in data file
# EXP_STAT=                    0 / Science data processing status (0=good)
#
#               PROPOSAL INFORMATION
#
# ...

# %% [markdown]
# ### Another?

# %%
ifile2 = '/u/xavier/Raw_IGMspec/HST_Cooksey/PKS2005-489/FUSE/PKS2005-489lif1a.fits'

# %%
hdu2 = fits.open(ifile2)

# %%
hdu2.info()
# Out:
# Filename: /u/xavier/Raw_IGMspec/HST_Cooksey/PKS2005-489/FUSE/PKS2005-489lif1a.fits
# No.    Name         Type      Cards   Dimensions   Format
# 0    PRIMARY     PrimaryHDU       4   ()
# 1                BinTableHDU     23   1R x 3C      [7333D, 7333E, 7333E]

# %%
hdu2[1].header
# Out:
# XTENSION= 'BINTABLE'           /Binary table written by MWRFITS v1.4a
# BITPIX  =                    8 /Required value
# NAXIS   =                    2 /Required value
# NAXIS1  =               117328 /Number of bytes per row
# NAXIS2  =                    1 /Number of rows
# PCOUNT  =                    0 /Normally 0 (no varying arrays)
# GCOUNT  =                    1 /Required value
# TFIELDS =                    3 /Number of columns in table
# COMMENT
# COMMENT  *** End of mandatory fields ***
# COMMENT
# COMMENT
# COMMENT  *** Column names ***
# COMMENT
# TTYPE1  = 'WAVE    '           /
# TTYPE2  = 'FLUX    '           /
# TTYPE3  = 'ERROR   '           /
# COMMENT
# COMMENT  *** Column formats ***
# COMMENT
# TFORM1  = '7333D   '           /
# TFORM2  = '7333E   '           /
# TFORM3  = '7333E   '           /

# %%
hdu2[1].header
# Out:
# XTENSION= 'BINTABLE'           /Binary table written by MWRFITS v1.4a
# BITPIX  =                    8 /Required value
# NAXIS   =                    2 /Required value
# NAXIS1  =               117328 /Number of bytes per row
# NAXIS2  =                    1 /Number of rows
# PCOUNT  =                    0 /Normally 0 (no varying arrays)
# GCOUNT  =                    1 /Required value
# TFIELDS =                    3 /Number of columns in table
# COMMENT
# COMMENT  *** End of mandatory fields ***
# COMMENT
# COMMENT
# COMMENT  *** Column names ***
# COMMENT
# TTYPE1  = 'WAVE    '           /
# TTYPE2  = 'FLUX    '           /
# TTYPE3  = 'ERROR   '           /
# COMMENT
# COMMENT  *** Column formats ***
# COMMENT
# TFORM1  = '7333D   '           /
# TFORM2  = '7333E   '           /
# TFORM3  = '7333E   '           /

# %%
hdu2[1].header.keys()[5]
# Out:
# 'PCOUNT'

# %% [markdown]
# ### Still checking

# %%
bad_fuse = '/raid/Raw_IGMspec//HST_Cooksey/Q0026+1259/FUSE/Q0026+1259lif2a.fits'

# %%
hdu = fits.open(bad_fuse)

# %%
hdu.info()
# Out:
# Filename: /raid/Raw_IGMspec//HST_Cooksey/Q0026+1259/FUSE/Q0026+1259lif2a.fits
# No.    Name         Type      Cards   Dimensions   Format
# 0    PRIMARY     PrimaryHDU       4   ()
# 1                BinTableHDU     23   1R x 3C      [7276E, 7276E, 7276E]

# %% [markdown]
# ### Untrim

# %%
bad_untrim = '/raid/Raw_IGMspec//HST_Cooksey/Q0026+1259/FUSE/Q0026+1259lif2a.fits.untrim'

# %%
hdu_untrim = fits.open(bad_untrim)

# %%
hdu_untrim[0].header
# Out:
# SIMPLE  =                    T / Data conforms to FITS standard
# BITPIX  =                   16 / Bits per data value
# NAXIS   =                    0 / Number of data axes
# EXTEND  =                    T / File may contain standard extensions
# NEXTEND =                    1 / Number of standard extensions
# GROUPS  =                    F / Image is in group format
# DATE    = '2007-05-09T22:08:56' / file creation date (YYYY-MM-DDThh:mm:ss UT)
#
#               DATA DESCRIPTION KEYWORDS
#
# TELESCOP= 'FUSE              ' / Telescope used to acquire data
# INSTRUME= 'FUV               ' / Instrument in use (one of FUV, FESA, or FESB)
# ROOTNAME= 'Q2060101999'        / Rootname of the observation set (ppppttooeee)
# FILENAME= 'Q20601019992alif4ttagfcal.fit' / Name of file
# FILETYPE= 'CALIBRATED EXTRACTED SPECTRUM' / Type of data found in data file
# EXP_STAT=                    0 / Science data processing status (0=good)
#
#               PROPOSAL INFORMATION
#
# ...

# %% [markdown]
# ### Pushing the untrim files into the several systems that need them...
#
# had to double kludge PKS2005-489

# %% [markdown]
# ## Read GHRS

# %%
ghrs_file = '/Users/xavier/Raw_IGMspec/HST_Cooksey/MRK335/GHRS/MRK335_GHRS_G160M_1221_F.fits'

# %%
hdu_ghrs = fits.open(ghrs_file)

# %%
hdu_ghrs.info()
# Out:
# Filename: /Users/xavier/Raw_IGMspec/HST_Cooksey/MRK335/GHRS/MRK335_GHRS_G160M_1221_F.fits
# No.    Name         Type      Cards   Dimensions   Format
# 0    PRIMARY     PrimaryHDU     294   (2041,)      float32

# %% [markdown]
# ----

# %% [markdown]
# ## Bad STIS headers
#
#     These STIS spectra are coadds of G??0M spectra with different central wavelengths. For example, PKS0405-123_G230M_F.fits spans roughly 1970–2200 Å, which is accomplished by coadding the following extracted 1D spectra (that you have):
#
#         PKS0405-12_G230M2014_F.fits (1970–2060 Å)
#         PKS0405-12_G230M2095_F.fits (2050–2140 Å)
#         PKS0405-12_G230M2176_F.fits (2130–2200 Å)
#
#     (full list at end of email). Each of those has an appropriate header.  The coadd of the individual 1D (*G??0M????_F.fits) was accomplished with my coadFUSE.pro (attached). This created a FUSE-format spectrum (*G??0M.fits) with the header from the highest-SNR spectrum of the coadd as a HISTORY comment (very kludgy). I put these files in the Dropbox folder:
#
#         H1821+643/STIS/H1821+643__G230M.fits
#
#             highest SNR: *G230M1687_F.fits
#
#         MRK1383/STIS/MRK1383_ST_G140M.fits
#
#             highest SNR: *G140M1222_F.fits
#
#         PG1116+215/STIS/PG1116+215_G140M.fits
#
#             highest SNR: *G140M1222_F.fits
#
#         PG1211+143/STIS/PG1211+143_G140M.fits
#
#             highest SNR: *G140M1222_F.fits
#
#         PKS0405-123/STIS/PKS0405-123_G230M.fits
#
#             highest SNR: *G230M2014_F.fits

# %% [markdown]
# ### Replacing G230M_F.fits with G230M.fits
#
#     Edited HSTQSO_pre-SM4.lst too
#     Removed _E and _c.fits files too
